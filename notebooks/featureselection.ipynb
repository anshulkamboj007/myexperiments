# %%
import pandas as pd
import numpy as np

# %%
from sklearn.feature_selection import mutual_info_regression

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('F:\my data science\ml_prac\myexperiments\datasets\Supermart Grocery Sales - Retail Analytics Dataset.csv')
df.head()
# Out:
#   Order ID Customer Name          Category      Sub Category         City
# 0      OD1        Harish      Oil & Masala           Masalas      Vellore  \
# 1      OD2         Sudha         Beverages     Health Drinks  Krishnagiri
# 2      OD3       Hussain       Food Grains      Atta & Flour   Perambalur
# 3      OD4       Jackson  Fruits & Veggies  Fresh Vegetables   Dharmapuri
# 4      OD5       Ridhesh       Food Grains   Organic Staples         Ooty
#
#    Order Date Region  Sales  Discount  Profit       State
# 0  11-08-2017  North   1254      0.12  401.28  Tamil Nadu
# 1  11-08-2017  South    749      0.18  149.80  Tamil Nadu
# 2  06-12-2017   West   2360      0.21  165.20  Tamil Nadu
# 3  10-11-2016  South    896      0.25   89.60  Tamil Nadu
# 4  10-11-2016  South   2355      0.26  918.45  Tamil Nadu

# %%
x=df.drop(['Order ID','Customer Name','Order Date','Sales'],axis=1)
x
# Out:
#                Category      Sub Category         City Region  Discount
# 0          Oil & Masala           Masalas      Vellore  North      0.12  \
# 1             Beverages     Health Drinks  Krishnagiri  South      0.18
# 2           Food Grains      Atta & Flour   Perambalur   West      0.21
# 3      Fruits & Veggies  Fresh Vegetables   Dharmapuri  South      0.25
# 4           Food Grains   Organic Staples         Ooty  South      0.26
# ...                 ...               ...          ...    ...       ...
# 9989  Eggs, Meat & Fish              Eggs      Madurai   West      0.16
# 9990             Bakery          Biscuits  Kanyakumari   West      0.26
# 9991        Food Grains              Rice         Bodi   West      0.16
# 9992       Oil & Masala            Spices   Pudukottai   West      0.15
# 9993        Food Grains      Atta & Flour  Tirunelveli   West      0.28
#
#       Profit       State
# 0     401.28  Tamil Nadu
# 1     149.80  Tamil Nadu
# ...

# %%
y=df['Sales']
y
# Out:
# 0       1254
# 1        749
# 2       2360
# 3        896
# 4       2355
#         ...
# 9989     945
# 9990    1195
# 9991    1567
# 9992    1659
# 9993    1034
# Name: Sales, Length: 9994, dtype: int64
