# %% [markdown]
# ### text classifier

# %%
import pandas as pd
import numpy as np
import string

# %%
import urllib.request
url = 'https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/hmm_class/edgar_allan_poe.txt'
filename = 'f1.txt'
urllib.request.urlretrieve(url, filename)

import urllib.request
url = 'https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/hmm_class/robert_frost.txt'
filename = 'f2.txt'
urllib.request.urlretrieve(url, filename)
# Out:
# ('f2.txt', <http.client.HTTPMessage at 0x1b38976a6e0>)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

# %%
import nltk
from nltk import word_tokenize
from nltk.corpus import wordnet

# %%
f1=pd.read_table('f1.txt',header=None)
f2=pd.read_table('f2.txt',header=None)

# %%
f1=pd.DataFrame(f1)
f2=pd.DataFrame(f2)

# %%
f1['label']=0
f2['label']=1

# %%
input_files=pd.concat([f1, f2])
input_files
# Out:
#                                                       0  label
# 0                LO! Death hath rear'd himself a throne      0
# 1                         In a strange city, all alone,      0
# 2                          Far down within the dim west      0
# 3     Where the good, and the bad, and the worst, an...      0
# 4                      Have gone to their eternal rest.      0
# ...                                                 ...    ...
# 1427    To say which buds are leaf and which are bloom.      1
# 1428             A feather-hammer gives a double knock.      1
# 1429              This Eden day is done at two o'clock.      1
# 1430         An hour of winter day might seem too short      1
# 1431   To make it worth life's while to wake and sport.      1
#
# [2154 rows x 2 columns]

# %%
input_files.rename(columns = {0:'text'}, inplace = True)

# %%
input_files.columns
# Out:
# Index(['text', 'label'], dtype='object')

# %%
input_files.reset_index(inplace = True, drop = True)

# %%
input_files['pro']=np.nan

# %%
input_files
df=input_files.copy()
df
# Out:
#                                                    text  label  pro
# 0                LO! Death hath rear'd himself a throne      0  NaN
# 1                         In a strange city, all alone,      0  NaN
# 2                          Far down within the dim west      0  NaN
# 3     Where the good, and the bad, and the worst, an...      0  NaN
# 4                      Have gone to their eternal rest.      0  NaN
# ...                                                 ...    ...  ...
# 2149    To say which buds are leaf and which are bloom.      1  NaN
# 2150             A feather-hammer gives a double knock.      1  NaN
# 2151              This Eden day is done at two o'clock.      1  NaN
# 2152         An hour of winter day might seem too short      1  NaN
# 2153   To make it worth life's while to wake and sport.      1  NaN
#
# [2154 rows x 3 columns]

# %%
for i in range(0,len(df)):
    df.iloc[i]['pro'] =df.iloc[i]['text'].rstrip().lower().translate(str.maketrans('','',string.punctuation))
# Out:
# C:\Users\anshul\AppData\Local\Temp\ipykernel_3224\3420087141.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.iloc[i]['pro'] =df.iloc[i]['text'].rstrip().lower().translate(str.maketrans('','',string.punctuation))

# %%
df
# Out:
#                                                    text  label  pro
# 0                LO! Death hath rear'd himself a throne      0  NaN
# 1                         In a strange city, all alone,      0  NaN
# 2                          Far down within the dim west      0  NaN
# 3     Where the good, and the bad, and the worst, an...      0  NaN
# 4                      Have gone to their eternal rest.      0  NaN
# ...                                                 ...    ...  ...
# 2149    To say which buds are leaf and which are bloom.      1  NaN
# 2150             A feather-hammer gives a double knock.      1  NaN
# 2151              This Eden day is done at two o'clock.      1  NaN
# 2152         An hour of winter day might seem too short      1  NaN
# 2153   To make it worth life's while to wake and sport.      1  NaN
#
# [2154 rows x 3 columns]

# %%
inp_text=[]
labels=[]

for i in input_files['text']:
    i=i.rstrip().lower()
    i=i.translate(str.maketrans('','',string.punctuation))
    #print(i)
    inp_text.append(i)

# %%
for i in input_files['label']:
    #print(i)
    labels.append(i)

# %%
train_text,test_text,Ytrain,Ytest=train_test_split(inp_text,labels)

# %%
len(Ytrain),len(Ytest)
# Out:
# (1615, 539)

# %%
train_text[:5]
# Out:
# ['then my heart it grew ashen and sober',
#  'back out of all this now too much for us',
#  'and if youre lost enough to find yourself',
#  'he want but fifteen at the time they say',
#  'with the brook going by below the yard']

# %%
Ytrain[:5]
# Out:
# [0, 1, 1, 1, 1]

# %%
idx=1
word2idx={'<unk>':0}

# %%
for text in train_text:
    tokens=text.split()
    for token in tokens:
        if token not in word2idx:
            word2idx[token]=idx
            idx+=1

# %%
word2idx
# Out:
# {'<unk>': 0,
#  'then': 1,
#  'my': 2,
#  'heart': 3,
#  'it': 4,
#  'grew': 5,
#  'ashen': 6,
#  'and': 7,
#  'sober': 8,
#  'back': 9,
#  'out': 10,
#  'of': 11,
#  'all': 12,
#  'this': 13,
#  'now': 14,
#  'too': 15,
#  'much': 16,
#  'for': 17,
#  'us': 18,
#  'if': 19,
#  'youre': 20,
#  'lost': 21,
#  'enough': 22,
#  'to': 23,
#  'find': 24,
#  'yourself': 25,
#  'he': 26,
#  'want': 27,
#  'but': 28,
#  'fifteen': 29,
#  'at': 30,
#  'the': 31,
#  'time': 32,
#  'they': 33,
#  'say': 34,
#  'with': 35,
#  'brook': 36,
#  'going': 37,
#  'by': 38,
#  'below': 39,
#  'yard': 40,
#  'experts': 41,
#  'said': 42,
#  'that': 43,
#  'deep': 44,
#  'down': 45,
#  'in': 46,
#  'mountain': 47,
#  'on': 48,
#  'motorcars': 49,
#  'im': 50,
#  'asked': 51,
#  'i': 52,
#  'spell': 53,
#  'so': 54,
#  'could': 55,
#  'hold': 56,
#  'them': 57,
#  'as': 58,
#  'were': 59,
#  'hes': 60,
#  'off': 61,
#  'setting': 62,
#  'traps': 63,
#  'stock': 64,
#  'a': 65,
#  'village': 66,
#  'library': 67,
#  'sigmas': 68,
#  'taus': 69,
#  'no': 70,
#  'its': 71,
#  'misting': 72,
#  'lets': 73,
#  'be': 74,
#  'fair': 75,
#  'bade': 76,
#  'me': 77,
#  'pause': 78,
#  'before': 79,
#  'gardengate': 80,
#  'truest': 81,
#  'most': 82,
#  'fervently': 83,
#  'devoted': 84,
#  'stardials': 85,
#  'hinted': 86,
#  'morn': 87,
#  'theyve': 88,
#  'got': 89,
#  'settled': 90,
#  'wrong': 91,
#  'can': 92,
#  'prove': 93,
#  'being': 94,
#  'cut': 95,
#  'from': 96,
#  'friends': 97,
#  'faintest': 98,
#  'restless': 99,
#  'rustling': 100,
#  'ran': 101,
#  'through': 102,
#  'hope': 103,
#  'beauty': 104,
#  'tonight': 105,
#  'stopped': 106,
#  'door': 107,
#  'tomb': 108,
#  'whose': 109,
#  'heartstrings': 110,
#  'are': 111,
#  'lute': 112,
#  'particular': 113,
#  'oclock': 114,
#  'fear': 115,
#  'treading': 116,
#  'upon': 117,
#  'looked': 118,
#  'up': 119,
#  'slippery': 120,
#  'slope': 121,
#  'you': 122,
#  'mean': 123,
#  'thats': 124,
#  'johns': 125,
#  'idea': 126,
#  'doth': 127,
#  'oer': 128,
#  'pass': 129,
#  'when': 130,
#  'th': 131,
#  'expanding': 132,
#  'eye': 133,
#  'fever': 134,
#  'minute': 135,
#  'see': 136,
#  'theres': 137,
#  'something': 138,
#  'may': 139,
#  'seem': 140,
#  'should': 141,
#  'have': 142,
#  'been': 143,
#  'quarry': 144,
#  'took': 145,
#  'one': 146,
#  'less': 147,
#  'traveled': 148,
#  'made': 149,
#  'tutelar': 150,
#  'shrine': 151,
#  'such': 152,
#  'is': 153,
#  'isnt': 154,
#  'worth': 155,
#  'mortgage': 156,
#  'front': 157,
#  'town': 158,
#  'hall': 159,
#  'id': 160,
#  'left': 161,
#  'him': 162,
#  'hitched': 163,
#  'agony': 164,
#  'sobbed': 165,
#  'letting': 166,
#  'sink': 167,
#  'her': 168,
#  'sun': 169,
#  'stars': 170,
#  'whence': 171,
#  'had': 172,
#  'drawn': 173,
#  'forth': 174,
#  'fervor': 175,
#  'thy': 176,
#  'steered': 177,
#  'was': 178,
#  'really': 179,
#  'straight': 180,
#  'away': 181,
#  'never': 182,
#  'done': 183,
#  'thing': 184,
#  'did': 185,
#  'son': 186,
#  'looks': 187,
#  'surprised': 188,
#  'end': 189,
#  'lie': 190,
#  'we': 191,
#  'there': 192,
#  'anything': 193,
#  'john': 194,
#  'bought': 195,
#  'paid': 196,
#  'bill': 197,
#  'beads': 198,
#  'eden': 199,
#  'sank': 200,
#  'grief': 201,
#  'fiftyfive': 202,
#  'know': 203,
#  'day': 204,
#  'wouldnt': 205,
#  'tell': 206,
#  'what': 207,
#  'our': 208,
#  'path': 209,
#  'liquescent': 210,
#  'imbued': 211,
#  'poor': 212,
#  'old': 213,
#  'man': 214,
#  'would': 215,
#  'right': 216,
#  'ashes': 217,
#  'will': 218,
#  'spring': 219,
#  'grow': 220,
#  'steeple': 221,
#  'promised': 222,
#  'toffile': 223,
#  'cruel': 224,
#  'hath': 225,
#  'ever': 226,
#  'told': 227,
#  'or': 228,
#  'thought': 229,
#  'scarce': 230,
#  'which': 231,
#  'prize': 232,
#  'high': 233,
#  'come': 234,
#  'here': 235,
#  'ill': 236,
#  'show': 237,
#  'apple': 238,
#  'tree': 239,
#  'bird': 240,
#  'an': 241,
#  'angelic': 242,
#  'gift': 243,
#  'oh': 244,
#  'kept': 245,
#  'first': 246,
#  'another': 247,
#  'worship': 248,
#  'star': 249,
#  'doubted': 250,
#  'against': 251,
#  'attic': 252,
#  'nailed': 253,
#  'distinct': 254,
#  'duplicate': 255,
#  'horn': 256,
#  'always': 257,
#  'witchs': 258,
#  'motto': 259,
#  'anyway': 260,
#  'cant': 261,
#  'get': 262,
#  'root': 263,
#  'attempting': 264,
#  'stray': 265,
#  'set': 266,
#  'lot': 267,
#  'dont': 268,
#  'record': 269,
#  'where': 270,
#  'driven': 271,
#  'rain': 272,
#  'wet': 273,
#  'swollen': 274,
#  'shine': 275,
#  'bright': 276,
#  'eyes': 277,
#  'partial': 278,
#  'greatgrandmother': 279,
#  'ten': 280,
#  'winter': 281,
#  'eve': 282,
#  'she': 283,
#  'replied': 284,
#  'ulalume': 285,
#  'mounted': 286,
#  'bareback': 287,
#  'earth': 288,
#  'plain': 289,
#  'statement': 290,
#  'relationship': 291,
#  'road': 292,
#  'matter': 293,
#  'several': 294,
#  'miles': 295,
#  'broke': 296,
#  'trance': 297,
#  'make': 298,
#  'suspicious': 299,
#  'roof': 300,
#  'float': 301,
#  'flow': 302,
#  'admiring': 303,
#  'natures': 304,
#  'universal': 305,
#  'throne': 306,
#  'ah': 307,
#  'night': 308,
#  'nights': 309,
#  'year': 310,
#  'last': 311,
#  'years': 312,
#  'berries': 313,
#  'shining': 314,
#  'scarlet': 315,
#  'red': 316,
#  'very': 317,
#  'hours': 318,
#  'breathing': 319,
#  'low': 320,
#  'who': 321,
#  'owe': 322,
#  'thee': 323,
#  'gratitude': 324,
#  'home': 325,
#  'only': 326,
#  'field': 327,
#  'bland': 328,
#  'repose': 329,
#  'well—i—be—': 330,
#  'frogs': 331,
#  'peeping': 332,
#  'thousand': 333,
#  'shrill': 334,
#  'bead': 335,
#  'silver': 336,
#  'water': 337,
#  'more': 338,
#  'pride': 339,
#  'ancestry': 340,
#  'yankees': 341,
#  'though': 342,
#  'runs': 343,
#  'unbridled': 344,
#  'course': 345,
#  'wasnt': 346,
#  'anyone': 347,
#  'two': 348,
#  'weeks': 349,
#  'since': 350,
#  'those': 351,
#  'poetesss': 352,
#  'life': 353,
#  'live': 354,
#  'again': 355,
#  'not': 356,
#  'faith': 357,
#  'godliness': 358,
#  'level': 359,
#  'nearer': 360,
#  'heaven': 361,
#  'overhead': 362,
#  'glimpse': 363,
#  'curtain': 364,
#  'laces': 365,
#  'swellings': 366,
#  'hint': 367,
#  'winds': 368,
#  'strange': 369,
#  'muffled': 370,
#  'times': 371,
#  'over': 372,
#  'marrying': 373,
#  'father': 374,
#  'his': 375,
#  'journey': 376,
#  'thou': 377,
#  'ghost': 378,
#  'amid': 379,
#  'entombing': 380,
#  'trees': 381,
#  'hoed': 382,
#  'little': 383,
#  'yesterday': 384,
#  'dead': 385,
#  'young': 386,
#  'folk': 387,
#  'held': 388,
#  'some': 389,
#  'each': 390,
#  'other': 391,
#  'late': 392,
#  'remembered': 393,
#  'dank': 394,
#  'tarn': 395,
#  'auber': 396,
#  'cannot': 397,
#  'write': 398,
#  'speak': 399,
#  'think': 400,
#  'shouted': 401,
#  'shut': 402,
#  'bedroom': 403,
#  'newcut': 404,
#  'narrow': 405,
#  'gap': 406,
#  'wait': 407,
#  'until': 408,
#  'give': 409,
#  'hand': 410,
#  'boys': 411,
#  'bad': 412,
#  'hunters': 413,
#  'known': 414,
#  'do': 415,
#  'dalton': 416,
#  'someday': 417,
#  'fortune': 418,
#  'bless': 419,
#  'expense': 420,
#  'reach': 421,
#  'impulse': 422,
#  'knob': 423,
#  'sense': 424,
#  'having': 425,
#  'together': 426,
#  'must': 427,
#  'mind': 428,
#  'certain': 429,
#  'coolness': 430,
#  'whod': 431,
#  'marry': 432,
#  'mess': 433,
#  'grace': 434,
#  'than': 435,
#  'let': 436,
#  'things': 437,
#  'smash': 438,
#  'couldnt': 439,
#  'climb': 440,
#  'tight': 441,
#  'buried': 442,
#  'under': 443,
#  'snow': 444,
#  'grandsir': 445,
#  'stark': 446,
#  'distinctly': 447,
#  'ultimate': 448,
#  'climes': 449,
#  'pole': 450,
#  'written': 451,
#  'sweet': 452,
#  'sister': 453,
#  'like': 454,
#  'love': 455,
#  'warm': 456,
#  'bed': 457,
#  'both': 458,
#  'united': 459,
#  'strengths': 460,
#  'save': 461,
#  'divine': 462,
#  'light': 463,
#  'thine': 464,
#  'knows': 465,
#  'story': 466,
#  'twas': 467,
#  'pale': 468,
#  'dim': 469,
#  'match': 470,
#  'flame': 471,
#  'vulture': 472,
#  'wings': 473,
#  'dull': 474,
#  'realities': 475,
#  'half': 476,
#  'boring': 477,
#  'climbing': 478,
#  'drew': 479,
#  'passport': 480,
#  'long': 481,
#  'ago': 482,
#  'writer': 483,
#  'these': 484,
#  'lines': 485,
#  'while': 486,
#  'am': 487,
#  'yet': 488,
#  'alive': 489,
#  'wonder': 490,
#  'cold': 491,
#  'coming': 492,
#  'even': 493,
#  'meridian': 494,
#  'glare': 495,
#  'seraph': 496,
#  'spread': 497,
#  'pinion': 498,
#  'might': 499,
#  'well': 500,
#  'herself': 501,
#  'liked': 502,
#  'best': 503,
#  'own': 504,
#  'makes': 505,
#  'head': 506,
#  'spin': 507,
#  'build': 508,
#  'chimney': 509,
#  'clear': 510,
#  'ground': 511,
#  'hens': 512,
#  'blowing': 513,
#  'about': 514,
#  'myself': 515,
#  'thinks': 516,
#  'whom': 517,
#  'talk': 518,
#  'simple': 519,
#  'loss': 520,
#  'beyond': 521,
#  'utterance': 522,
#  'human': 523,
#  'tongue': 524,
#  'joy': 525,
#  'hate': 526,
#  'cellar': 527,
#  'astartes': 528,
#  'bediamonded': 529,
#  'crescent': 530,
#  'birch': 531,
#  'tottering': 532,
#  'above': 533,
#  'disappeared': 534,
#  'ended': 535,
#  'far': 536,
#  'wake': 537,
#  'sigh': 538,
#  'till': 539,
#  'caught': 540,
#  'wind': 541,
#  'opening': 542,
#  'covers': 543,
#  'pens': 544,
#  'thrills': 545,
#  'headboard': 546,
#  'wants': 547,
#  'help': 548,
#  'softmurmured': 549,
#  'words': 550,
#  'fulfilled': 551,
#  'serious': 552,
#  'youd': 553,
#  'tempt': 554,
#  'strung': 555,
#  'your': 556,
#  'hair': 557,
#  'wont': 558,
#  'hurt': 559,
#  'summer': 560,
#  'lavas': 561,
#  'restlessly': 562,
#  'roll': 563,
#  'groping': 564,
#  'after': 565,
#  'jam': 566,
#  'marshall': 567,
#  'look': 568,
#  'donkeys': 569,
#  'ears': 570,
#  'converging': 571,
#  'slides': 572,
#  'avalanches': 573,
#  'good': 574,
#  'unembodied': 575,
#  'essence': 576,
#  'rare': 577,
#  'radiant': 578,
#  'flowers': 579,
#  'song': 580,
#  'french': 581,
#  'indian': 582,
#  'esquimaux': 583,
#  'someones': 584,
#  'work': 585,
#  'once': 586,
#  'thus': 587,
#  'pacified': 588,
#  'psyche': 589,
#  'kissed': 590,
#  'gets': 591,
#  'sort': 592,
#  'bakeshop': 593,
#  'meals': 594,
#  'twenty': 595,
#  'others': 596,
#  'wriggling': 597,
#  'speed': 598,
#  'confusion': 599,
#  'aglitter': 600,
#  'dreams': 601,
#  'ye': 602,
#  'deliverers': 603,
#  'athens': 604,
#  'shame': 605,
#  'uplifting': 606,
#  'finger': 607,
#  'windbreak': 608,
#  'sits': 609,
#  'sings': 610,
#  'chandelier': 611,
#  'lifts': 612,
#  'gaunt': 613,
#  'luxuriating': 614,
#  'beast': 615,
#  'sorry': 616,
#  'travel': 617,
#  'undo': 618,
#  'hed': 619,
#  'saturn': 620,
#  'mars': 621,
#  'stained': 622,
#  'vegetation': 623,
#  'hail': 624,
#  'presence': 625,
#  'morning': 626,
#  'ancestral': 627,
#  'memories': 628,
#  'between': 629,
#  'doesnt': 630,
#  'higher': 631,
#  'fell': 632,
#  'upturnd': 633,
#  'faces': 634,
#  'roses': 635,
#  'leaf': 636,
#  'stir': 637,
#  'equally': 638,
#  'lay': 639,
#  'rocks': 640,
#  'beside': 641,
#  'waterfall': 642,
#  'spirit': 643,
#  'knew': 644,
#  'hour': 645,
#  'youve': 646,
#  'noted': 647,
#  'lake': 648,
#  'go': 649,
#  'sleep': 650,
#  'woods': 651,
#  'wilds': 652,
#  'mountains': 653,
#  'intense': 654,
#  'new': 655,
#  'cottage': 656,
#  'ancient': 657,
#  'spot': 658,
#  'any': 659,
#  'died': 660,
#  'coat': 661,
#  'seated': 662,
#  'passing': 663,
#  'because': 664,
#  'grassy': 665,
#  'wanted': 666,
#  'wear': 667,
#  'seen': 668,
#  'courage': 669,
#  'nearest': 670,
#  'resembles': 671,
#  'remember': 672,
#  'interrupted': 673,
#  'cry': 674,
#  'hear': 675,
#  'today': 676,
#  'ought': 677,
#  'sometime': 678,
#  'means': 679,
#  'seven': 680,
#  'caves': 681,
#  'came': 682,
#  'heat': 683,
#  'slowly': 684,
#  'hazes': 685,
#  'nothing': 686,
#  'listen': 687,
#  'lean': 688,
#  'resurrection': 689,
#  'deepburied': 690,
#  'jupiter': 691,
#  'levin': 692,
#  'longer': 693,
#  'axis': 694,
#  'hadnt': 695,
#  'gnaw': 696,
#  'posts': 697,
#  'wed': 698,
#  'ourselves': 699,
#  'guide': 700,
#  'alas': 701,
#  'magical': 702,
#  'sad': 703,
#  'sound': 704,
#  'flickers': 705,
#  'sky': 706,
#  'just': 707,
#  'ahead': 708,
#  'foot': 709,
#  'crew': 710,
#  'failed': 711,
#  'headed': 712,
#  'for—': 713,
#  'outwalked': 714,
#  'furthest': 715,
#  'city': 716,
#  'way': 717,
#  'remembering': 718,
#  'take': 719,
#  'polish': 720,
#  'crust': 721,
#  'sometimes': 722,
#  'possessed': 723,
#  'keep': 724,
#  'accounts': 725,
#  'fervour': 726,
#  'power': 727,
#  'heard': 728,
#  'place': 729,
#  'eased': 730,
#  'copy': 731,
#  'mustnt': 732,
#  'bear': 733,
#  'hard': 734,
#  'comers': 735,
#  'dream': 736,
#  'harpstring': 737,
#  'broken': 738,
#  'clara': 739,
#  'robinson': 740,
#  'wreathed': 741,
#  'myrtle': 742,
#  'sword': 743,
#  'conceal': 744,
#  'bow': 745,
#  'cased': 746,
#  'world': 747,
#  'gone': 748,
#  'killed': 749,
#  'instead': 750,
#  'ghoulhaunted': 751,
#  'woodland': 752,
#  'weir': 753,
#  'spoke': 754,
#  'lettered': 755,
#  'davis': 756,
#  'graciously': 757,
#  'thrown': 758,
#  'into': 759,
#  'mother': 760,
#  'deareye': 761,
#  'talkedof': 762,
#  'mystery': 763,
#  'birth': 764,
#  'thrill': 765,
#  'single': 766,
#  'kiss': 767,
#  'wild': 768,
#  'backs': 769,
#  'creation': 770,
#  'fabric': 771,
#  'bodies': 772,
#  'giddy': 773,
#  'legends': 774,
#  'separate': 775,
#  'coops': 776,
#  'their': 777,
#  'plumage': 778,
#  'dark': 779,
#  'gnawed': 780,
#  'hitching': 781,
#  'sproutlands': 782,
#  'flourish': 783,
#  'axe': 784,
#  'has': 785,
#  'welcomed': 786,
#  'chance': 787,
#  'lave': 788,
#  'shoes': 789,
#  'mighty': 790,
#  'moisture': 791,
#  'color': 792,
#  'odor': 793,
#  'thicken': 794,
#  'western': 795,
#  'couch': 796,
#  'thundercloud': 797,
#  'seems': 798,
#  'housework': 799,
#  'besides': 800,
#  'isola': 801,
#  'doro': 802,
#  'fior': 803,
#  'di': 804,
#  'levante': 805,
#  'breath': 806,
#  'air': 807,
#  'forty': 808,
#  'farm': 809,
#  'builder': 810,
#  'building': 811,
#  'house': 812,
#  'vow': 813,
#  'near': 814,
#  'elfin': 815,
#  'green': 816,
#  'grass': 817,
#  'avengers': 818,
#  'libertys': 819,
#  'wrongs': 820,
#  'harmodious': 821,
#  'gallant': 822,
#  'pointed': 823,
#  'cypress': 824,
#  'roamed': 825,
#  'soul': 826,
#  'shaded': 827,
#  'branch': 828,
#  'leave': 829,
#  'likeness': 830,
#  'surprise': 831,
#  'thrilly': 832,
#  'tourist': 833,
#  'free': 834,
#  'kick': 835,
#  'folks': 836,
#  'small': 837,
#  'fist': 838,
#  'bushy': 839,
#  'hide': 840,
#  'angels': 841,
#  'tenanted': 842,
#  'watched': 843,
#  'holes': 844,
#  'least': 845,
#  'solace': 846,
#  'cane': 847,
#  'knock': 848,
#  'swarm': 849,
#  'still': 850,
#  'scuttled': 851,
#  'fast': 852,
#  'guess': 853,
#  'estelle': 854,
#  'filled': 855,
#  'purse': 856,
#  'stood': 857,
#  'feet': 858,
#  'thoughts': 859,
#  'palsied': 860,
#  'sere': 861,
#  'leaves': 862,
#  'crisped': 863,
#  'state': 864,
#  'glory': 865,
#  'befitting': 866,
#  'origin': 867,
#  'family': 868,
#  'hog': 869,
#  'reeve': 870,
#  'march': 871,
#  'meeting': 872,
#  'warren': 873,
#  'paradise': 874,
#  'pairing': 875,
#  'ends': 876,
#  'acquainted': 877,
#  'sell': 878,
#  'sos': 879,
#  'comfort': 880,
#  'sew': 881,
#  'terror': 882,
#  'mossy': 883,
#  'banks': 884,
#  'meandering': 885,
#  'paths': 886,
#  'transforming': 887,
#  'charms': 888,
#  'shall': 889,
#  'please': 890,
#  'present': 891,
#  'grave': 892,
#  'existence': 893,
#  'plane': 894,
#  'put': 895,
#  'wantonest': 896,
#  'singing': 897,
#  'birds': 898,
#  'nor': 899,
#  'named': 900,
#  'yes': 901,
#  'enamored': 902,
#  'moon': 903,
#  'married': 904,
#  'tinkling': 905,
#  'throats': 906,
#  'invisible': 907,
#  'published': 908,
#  'raised': 909,
#  'voice': 910,
#  'closing': 911,
#  'fresh': 912,
#  'blade': 913,
#  'entwine': 914,
#  'untidy': 915,
#  'achilles': 916,
#  'diomed': 917,
#  'rest': 918,
#  'skiff': 919,
#  'bathe': 920,
#  'crystalline': 921,
#  'ive': 922,
#  'built': 923,
#  'big': 924,
#  'church': 925,
#  'organ': 926,
#  'how': 927,
#  'neighbour': 928,
#  'fill': 929,
#  'worlds': 930,
#  'given': 931,
#  'nothings': 932,
#  'pays': 933,
#  'common': 934,
#  'weak': 935,
#  'idols': 936,
#  'diamond': 937,
#  'music': 938,
#  'felt': 939,
#  'same': 940,
#  'entombed': 941,
#  'highest': 942,
#  'noon': 943,
#  'source': 944,
#  'fate': 945,
#  'name': 946,
#  'also': 947,
#  'sorrow': 948,
#  'passionate': 949,
#  'fit': 950,
#  'legs': 951,
#  'army': 952,
#  'mule': 953,
#  'embalmed': 954,
#  'echoing': 955,
#  'songs': 956,
#  'used': 957,
#  'robinsons': 958,
#  'sybilic': 959,
#  'splendor': 960,
#  'beaming': 961,
#  'saw': 962,
#  'troubles': 963,
#  'feel': 964,
#  'hurried': 965,
#  'whats': 966,
#  'manner': 967,
#  'farmers': 968,
#  'around': 969,
#  'twice': 970,
#  'streams': 971,
#  'turrets': 972,
#  'silently': 973,
#  'bring': 974,
#  'chalkpile': 975,
#  'supposed': 976,
#  'mad': 977,
#  'office': 978,
#  'illumine': 979,
#  'enkindle': 980,
#  'sitting': 981,
#  'standing': 982,
#  'chose': 983,
#  'budded': 984,
#  'boughs': 985,
#  'piled': 986,
#  'trying': 987,
#  'beaded': 988,
#  'fur': 989,
#  'dyou': 990,
#  'person': 991,
#  'related': 992,
#  'smell': 993,
#  'feathers': 994,
#  'mist': 995,
#  'footstep': 996,
#  'stirred': 997,
#  'hated': 998,
#  'slept': 999,
#  ...}

# %%
len(word2idx)
# Out:
# 2541
