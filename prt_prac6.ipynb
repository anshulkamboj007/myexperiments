# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('df_arabica_clean.csv')
df.head(3)
# Out:
#    Unnamed: 0  ID Country of Origin                 Farm Name
# 0           0   0          Colombia          Finca El Paraiso  \
# 1           1   1            Taiwan  Royal Bean Geisha Estate
# 2           2   2              Laos        OKLAO coffee farms
#
#                                 Lot Number                           Mill
# 0                               CQU2022015               Finca El Paraiso  \
# 1  The 2022 Pacific Rim Coffee Summit,T037       Royal Bean Geisha Estate
# 2  The 2022 Pacific Rim Coffee Summit,LA01  oklao coffee processing plant
#
#   ICO Number                   Company   Altitude                Region  ...
# 0        NaN      Coffee Quality Union  1700-1930        Piendamo,Cauca  ...  \
# 1        NaN  Taiwan Coffee Laboratory       1200                Chiayi  ...
# 2        NaN  Taiwan Coffee Laboratory       1300  Laos Borofen Plateau  ...
#
#   Total Cup Points  Moisture Percentage Category One Defects Quakers
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 41 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             207 non-null    int64
#  1   ID                     207 non-null    int64
#  2   Country of Origin      207 non-null    object
#  3   Farm Name              205 non-null    object
#  4   Lot Number             206 non-null    object
#  5   Mill                   204 non-null    object
#  6   ICO Number             75 non-null     object
#  7   Company                207 non-null    object
#  8   Altitude               206 non-null    object
#  9   Region                 205 non-null    object
#  10  Producer               206 non-null    object
#  11  Number of Bags         207 non-null    int64
#  12  Bag Weight             207 non-null    object
#  13  In-Country Partner     207 non-null    object
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0                 0
# ID                         0
# Country of Origin          0
# Farm Name                  2
# Lot Number                 1
# Mill                       3
# ICO Number               132
# Company                    0
# Altitude                   1
# Region                     2
# Producer                   1
# Number of Bags             0
# Bag Weight                 0
# In-Country Partner         0
# Harvest Year               0
# Grading Date               0
# Owner                      0
# Variety                    6
# Status                     0
# Processing Method          5
# Aroma                      0
# Flavor                     0
# Aftertaste                 0
# Acidity                    0
# Body                       0
# Balance                    0
# Uniformity                 0
# Clean Cup                  0
# Sweetness                  0
# Overall                    0
# Defects                    0
# Total Cup Points           0
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Country of Origin', 'Farm Name', 'Lot Number',
#        'Mill', 'ICO Number', 'Company', 'Altitude', 'Region', 'Producer',
#        'Number of Bags', 'Bag Weight', 'In-Country Partner', 'Harvest Year',
#        'Grading Date', 'Owner', 'Variety', 'Status', 'Processing Method',
#        'Aroma', 'Flavor', 'Aftertaste', 'Acidity', 'Body', 'Balance',
#        'Uniformity', 'Clean Cup', 'Sweetness', 'Overall', 'Defects',
#        'Total Cup Points', 'Moisture Percentage', 'Category One Defects',
#        'Quakers', 'Color', 'Category Two Defects', 'Expiration',
#        'Certification Body', 'Certification Address', 'Certification Contact'],
#       dtype='object')

# %%
#dropping 'Unnamed: 0', 'ID'
df.drop(['Unnamed: 0', 'ID','ICO Number'],axis=1,inplace=True)

# %%
df.head(2)
# Out:
#   Country of Origin                 Farm Name
# 0          Colombia          Finca El Paraiso  \
# 1            Taiwan  Royal Bean Geisha Estate
#
#                                 Lot Number                      Mill
# 0                               CQU2022015          Finca El Paraiso  \
# 1  The 2022 Pacific Rim Coffee Summit,T037  Royal Bean Geisha Estate
#
#                     Company   Altitude          Region               Producer
# 0      Coffee Quality Union  1700-1930  Piendamo,Cauca  Diego Samuel Bermudez  \
# 1  Taiwan Coffee Laboratory       1200          Chiayi                    曾福森
#
#    Number of Bags Bag Weight  ... Total Cup Points Moisture Percentage
# 0               1      35 kg  ...            89.33                11.8  \
# 1               1      80 kg  ...            87.58                10.5
#
#   Category One Defects Quakers       Color Category Two Defects
# 0                    0       0       green                    3  \
# ...

# %%
df.dropna(inplace=True,axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 30 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country of Origin      207 non-null    object
#  1   Company                207 non-null    object
#  2   Number of Bags         207 non-null    int64
#  3   Bag Weight             207 non-null    object
#  4   In-Country Partner     207 non-null    object
#  5   Harvest Year           207 non-null    object
#  6   Grading Date           207 non-null    object
#  7   Owner                  207 non-null    object
#  8   Status                 207 non-null    object
#  9   Aroma                  207 non-null    float64
#  10  Flavor                 207 non-null    float64
#  11  Aftertaste             207 non-null    float64
#  12  Acidity                207 non-null    float64
#  13  Body                   207 non-null    float64
# ...

# %%
df.drop(['Certification Address', 'Certification Contact','Expiration','In-Country Partner','Status','Grading Date','Owner'],axis=1,inplace=True)

# %%
df.head(2)
# Out:
#   Country of Origin                   Company  Number of Bags Bag Weight
# 0          Colombia      Coffee Quality Union               1      35 kg  \
# 1            Taiwan  Taiwan Coffee Laboratory               1      80 kg
#
#   Harvest Year  Aroma  Flavor  Aftertaste  Acidity  Body  ...  Sweetness
# 0  2021 / 2022   8.58     8.5        8.42     8.58  8.25  ...       10.0  \
# 1  2021 / 2022   8.50     8.5        7.92     8.00  7.92  ...       10.0
#
#    Overall  Defects  Total Cup Points  Moisture Percentage
# 0     8.58      0.0             89.33                 11.8  \
# 1     8.50      0.0             87.58                 10.5
#
#    Category One Defects  Quakers       Color  Category Two Defects
# 0                     0        0       green                     3  \
# 1                     0        0  blue-green                     0
#
#                  Certification Body
# 0             Japan Coffee Exchange
# 1  Taiwan Coffee Laboratory 台灣咖啡研究室
#
# [2 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country of Origin     207 non-null    object
#  1   Company               207 non-null    object
#  2   Number of Bags        207 non-null    int64
#  3   Bag Weight            207 non-null    object
#  4   Harvest Year          207 non-null    object
#  5   Aroma                 207 non-null    float64
#  6   Flavor                207 non-null    float64
#  7   Aftertaste            207 non-null    float64
#  8   Acidity               207 non-null    float64
#  9   Body                  207 non-null    float64
#  10  Balance               207 non-null    float64
#  11  Uniformity            207 non-null    float64
#  12  Clean Cup             207 non-null    float64
#  13  Sweetness             207 non-null    float64
# ...

# %%
df['Country of Origin'].value_counts()
# Out:
# Country of Origin
# Taiwan                          61
# Guatemala                       21
# Colombia                        19
# Honduras                        13
# Thailand                        12
# Ethiopia                        11
# Brazil                          10
# Costa Rica                       8
# Nicaragua                        7
# El Salvador                      7
# Tanzania, United Republic Of     6
# United States (Hawaii)           5
# Mexico                           4
# Peru                             4
# Vietnam                          4
# Uganda                           3
# Indonesia                        3
# Laos                             3
# Panama                           2
# Kenya                            2
# Madagascar                       1
# Myanmar                          1
# Name: count, dtype: int64

# %%
df['Company'].value_counts()
# Out:
# Company
# Taiwan Coffee Laboratory        51
# Taiwu Coffee Cooperative        25
# Coffee Quality Union            15
# Doi Tung Development Project     7
# Peter Schoenfeld, S.A.           6
#                                 ..
# Taylor Winch Coffee Ltd          1
# ECOM COLOMBIA                    1
# Exportadora Café California      1
# Coffee Quality Institute         1
# marubeni                         1
# Name: count, Length: 72, dtype: int64

# %%
df['Harvest Year'].value_counts()
# Out:
# Harvest Year
# 2021 / 2022    99
# 2022           48
# 2022 / 2023    42
# 2021           13
# 2023            3
# 2017 / 2018     1
# 2018 / 2019     1
# Name: count, dtype: int64

# %%
df['Harvest Year']=df['Harvest Year'].map({'2021 / 2022':'2021','2022 / 2023':'2022','2017 / 2018':'2017','2018 / 2019':'2018','2022':'2022','2021':'2021','2023':'2023'})

# %%
df['Harvest Year'].value_counts()
# Out:
# Harvest Year
# 2021    112
# 2022     90
# 2023      3
# 2017      1
# 2018      1
# Name: count, dtype: int64

# %%
df['Number of Bags'].value_counts()
# Out:
# Number of Bags
# 1       62
# 275     16
# 320     14
# 2       11
# 600     10
# 5        7
# 3        6
# 200      5
# 300      4
# 4        4
# 10       4
# 6        3
# 8        3
# 250      3
# 325      3
# 20       3
# 100      3
# 260      3
# 345      2
# 16       2
# 620      2
# 9        2
# 440      2
# 40       2
# 960      1
# 26       1
# 2240     1
# 141      1
# 22       1
# 540      1
# 150      1
# 32       1
# 77       1
# 13       1
# 125      1
# 500      1
# 14       1
# 120      1
# 55       1
# 50       1
# 285      1
# 635      1
# 375      1
# 35       1
# 430      1
# 19       1
# 584      1
# 340      1
# 74       1
# 66       1
# 632      1
# 80       1
# 25       1
# 70       1
# 343      1
# Name: count, dtype: int64

# %%
df['Bag Weight'].value_counts()
# Out:
# Bag Weight
# 30 kg       39
# 60 kg       31
# 69 kg       25
# 1 kg        14
# 15 kg       10
# 5 kg        10
# 2 kg         8
# 70 kg        6
# 100 kg       6
# 50 kg        6
# 10 kg        5
# 80 kg        4
# 35 kg        4
# 20 kg        3
# 12 kg        3
# 4 kg         2
# 25 kg        2
# 90 kg        2
# 45 kg        2
# 16 kg        2
# 13 kg        2
# 22 kg        2
# 19200 kg     2
# 8 kg         2
# 40 kg        1
# 32 kg        1
# 200 kg       1
# 3 kg         1
# 320 kg       1
# 6 kg         1
# 104 kg       1
# 110 kg       1
# 300 kg       1
# 36 kg        1
# 24 kg        1
# 48 kg        1
# 85 kg        1
# 27 kg        1
# 59 kg        1
# Name: count, dtype: int64

# %%
#dropping Bag Weight,Number of Bags as they dont indicate quality

# %%
df['Certification Body'].value_counts()
# Out:
# Certification Body
# Taiwan Coffee Laboratory 台灣咖啡研究室                                     83
# Japan Coffee Exchange                                                27
# Asociacion Nacional Del Café                                         14
# Instituto Hondureño del Café                                         10
# FABB Academy of Coffee                                                9
# Kenya Coffee Traders Association                                      8
# Specialty Coffee Association of Costa Rica                            7
# Blossom Valley International宸嶧國際                                      6
# METAD Agricultural Development plc                                    6
# Salvadoran Coffee Council                                             6
# Centro Agroecológico del Café A.C.                                    5
# Brazil Specialty Coffee Association                                   4
# NKG Quality Service (a division of Bernhard Rothfos Intercafé AG)     4
# ...

# %%
df.head(2)
# Out:
#   Country of Origin                   Company  Number of Bags Bag Weight
# 0          Colombia      Coffee Quality Union               1      35 kg  \
# 1            Taiwan  Taiwan Coffee Laboratory               1      80 kg
#
#   Harvest Year  Aroma  Flavor  Aftertaste  Acidity  Body  ...  Sweetness
# 0         2021   8.58     8.5        8.42     8.58  8.25  ...       10.0  \
# 1         2021   8.50     8.5        7.92     8.00  7.92  ...       10.0
#
#    Overall  Defects  Total Cup Points  Moisture Percentage
# 0     8.58      0.0             89.33                 11.8  \
# 1     8.50      0.0             87.58                 10.5
#
#    Category One Defects  Quakers       Color  Category Two Defects
# 0                     0        0       green                     3  \
# 1                     0        0  blue-green                     0
#
#                  Certification Body
# 0             Japan Coffee Exchange
# 1  Taiwan Coffee Laboratory 台灣咖啡研究室
#
# [2 rows x 23 columns]

# %%
df['Color'].value_counts()
# Out:
# Color
# green            101
# greenish          36
# bluish-green      21
# blue-green        12
# yellow-green      10
# brownish           9
# pale yellow        6
# yellow green       5
# yellowish          4
# yellow- green      1
# browish-green      1
# yello-green        1
# Name: count, dtype: int64

# %%
df['Color']=df['Color'].map({'green':'green','greenish':'green','bluish-green':'blue-green','blue-green':'blue-green','yellow-green':'yellow-green','brownish':'brownish','pale yellow':'pale yellow','yellow green':'yellow-green','yellowish':'yellowish','yellow- green':'yellow-green','browish-green':'browish-green','yello-green':'yellow-green'})

# %%
df.head(2)
# Out:
#   Country of Origin                   Company  Number of Bags Bag Weight
# 0          Colombia      Coffee Quality Union               1      35 kg  \
# 1            Taiwan  Taiwan Coffee Laboratory               1      80 kg
#
#   Harvest Year  Aroma  Flavor  Aftertaste  Acidity  Body  ...  Sweetness
# 0         2021   8.58     8.5        8.42     8.58  8.25  ...       10.0  \
# 1         2021   8.50     8.5        7.92     8.00  7.92  ...       10.0
#
#    Overall  Defects  Total Cup Points  Moisture Percentage
# 0     8.58      0.0             89.33                 11.8  \
# 1     8.50      0.0             87.58                 10.5
#
#    Category One Defects  Quakers       Color  Category Two Defects
# 0                     0        0       green                     3  \
# 1                     0        0  blue-green                     0
#
#                  Certification Body
# 0             Japan Coffee Exchange
# 1  Taiwan Coffee Laboratory 台灣咖啡研究室
#
# [2 rows x 23 columns]

# %%
df['Bag Weight'].value_counts()
# Out:
# Bag Weight
# 30 kg       39
# 60 kg       31
# 69 kg       25
# 1 kg        14
# 15 kg       10
# 5 kg        10
# 2 kg         8
# 70 kg        6
# 100 kg       6
# 50 kg        6
# 10 kg        5
# 80 kg        4
# 35 kg        4
# 20 kg        3
# 12 kg        3
# 4 kg         2
# 25 kg        2
# 90 kg        2
# 45 kg        2
# 16 kg        2
# 13 kg        2
# 22 kg        2
# 19200 kg     2
# 8 kg         2
# 40 kg        1
# 32 kg        1
# 200 kg       1
# 3 kg         1
# 320 kg       1
# 6 kg         1
# 104 kg       1
# 110 kg       1
# 300 kg       1
# 36 kg        1
# 24 kg        1
# 48 kg        1
# 85 kg        1
# 27 kg        1
# 59 kg        1
# Name: count, dtype: int64

# %%
df['Bag Weight(kg)']=df['Bag Weight'].str.split(' ',expand=True)[0].astype('Float64')

# %%
df['Bag Weight(kg)'].value_counts()
# Out:
# Bag Weight(kg)
# 30.0       39
# 60.0       31
# 69.0       25
# 1.0        14
# 15.0       10
# 5.0        10
# 2.0         8
# 70.0        6
# 100.0       6
# 50.0        6
# 10.0        5
# 80.0        4
# 35.0        4
# 20.0        3
# 12.0        3
# 4.0         2
# 25.0        2
# 90.0        2
# 45.0        2
# 16.0        2
# 13.0        2
# 22.0        2
# 19200.0     2
# 8.0         2
# 40.0        1
# 32.0        1
# 200.0       1
# 3.0         1
# 320.0       1
# 6.0         1
# 104.0       1
# 110.0       1
# 300.0       1
# 36.0        1
# 24.0        1
# 48.0        1
# 85.0        1
# 27.0        1
# 59.0        1
# Name: count, dtype: Int64

# %%
df.drop('Bag Weight',inplace=True,axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country of Origin     207 non-null    object
#  1   Company               207 non-null    object
#  2   Number of Bags        207 non-null    int64
#  3   Harvest Year          207 non-null    object
#  4   Aroma                 207 non-null    float64
#  5   Flavor                207 non-null    float64
#  6   Aftertaste            207 non-null    float64
#  7   Acidity               207 non-null    float64
#  8   Body                  207 non-null    float64
#  9   Balance               207 non-null    float64
#  10  Uniformity            207 non-null    float64
#  11  Clean Cup             207 non-null    float64
#  12  Sweetness             207 non-null    float64
#  13  Overall               207 non-null    float64
# ...

# %%
df['qty(kg)']=df['Bag Weight(kg)'] *df['Number of Bags']

# %%
df.drop('Bag Weight(kg)',inplace=True,axis=1)
df.drop('Number of Bags',inplace=True,axis=1)

# %%
df['qty(kg)'].value_counts()
# Out:
# qty(kg)
# 2.0        14
# 18975.0    13
# 18000.0    11
# 19200.0    11
# 100.0       9
#            ..
# 1050.0      1
# 26250.0     1
# 19050.0     1
# 19950.0     1
# 36000.0     1
# Name: count, Length: 93, dtype: Int64

# %%
df.head(2)
# Out:
#   Country of Origin                   Company Harvest Year  Aroma  Flavor
# 0          Colombia      Coffee Quality Union         2021   8.58     8.5  \
# 1            Taiwan  Taiwan Coffee Laboratory         2021   8.50     8.5
#
#    Aftertaste  Acidity  Body  Balance  Uniformity  ...  Overall  Defects
# 0        8.42     8.58  8.25     8.42        10.0  ...     8.58      0.0  \
# 1        7.92     8.00  7.92     8.25        10.0  ...     8.50      0.0
#
#    Total Cup Points  Moisture Percentage  Category One Defects  Quakers
# 0             89.33                 11.8                     0        0  \
# 1             87.58                 10.5                     0        0
#
#         Color  Category Two Defects                Certification Body  qty(kg)
# 0       green                     3             Japan Coffee Exchange     35.0
# 1  blue-green                     0  Taiwan Coffee Laboratory 台灣咖啡研究室     80.0
#
# [2 rows x 22 columns]

# %%
df.info(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country of Origin     207 non-null    object
#  1   Company               207 non-null    object
#  2   Harvest Year          207 non-null    object
#  3   Aroma                 207 non-null    float64
#  4   Flavor                207 non-null    float64
#  5   Aftertaste            207 non-null    float64
#  6   Acidity               207 non-null    float64
#  7   Body                  207 non-null    float64
#  8   Balance               207 non-null    float64
#  9   Uniformity            207 non-null    float64
#  10  Clean Cup             207 non-null    float64
#  11  Sweetness             207 non-null    float64
#  12  Overall               207 non-null    float64
#  13  Defects               207 non-null    float64
# ...

# %%
df['Category One Defects'].value_counts()
# Out:
# Category One Defects
# 0    193
# 1      6
# 2      5
# 3      1
# 4      1
# 5      1
# Name: count, dtype: int64

# %%
df['Category One Defects']=df['Category One Defects'].astype(object)
df['Category Two Defects']=df['Category Two Defects'].astype(object)

# %%
df['Quakers']=df['Quakers'].astype(object)
